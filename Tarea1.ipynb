# %% [markdown]
# ### **Ejercicio 1**

# %%
import numpy as np
import pandas as pd
days = [1,2,3,4,5] #Generamos una lista con los días
products = np.array(["#1","#2","#3"]) #Generamos un array con los productos

#Generamos un array de ceros del tamaño de los productos
ventas = np.zeros(len(products)) #Este array nos sirve de base para las ventas diarias

price = np.array([1,2,3]) #Generamos un array con los precios de cada producto

for i in range (len(days)):  #Hacemos un loop, el cual va a ser para los días
  print(f"Día {days[i]}")
  locals()["ventas_" + str(i)] = np.array(ventas) #Este comando sirve para generar un nuevo array para cada día con las ventas de cada producto
  for j in range (len(products)):   #Hacemos un loop dentro del loop anterior, el cual nos va a preguntar por el número de ventas de cada producto
    a=int(input(f"Número de ventas del producto {products[j]}: "))   #El comando dentro del input nos sirve para poder variar el nombre del producto a la hora de pedirlo
    locals()["ventas_" + str(i)][j] += a    #Con este comando vamos tomando el array del día pero la casilla de cada producto y le sumamos el valor que nos dieron
# Out:
# Día 1
# Número de ventas del producto #1: 1
# Número de ventas del producto #2: 2
# Número de ventas del producto #3: 3
# Día 2
# Número de ventas del producto #1: 4
# Número de ventas del producto #2: 5
# Número de ventas del producto #3: 6
# Día 3
# Número de ventas del producto #1: 7
# Número de ventas del producto #2: 8
# Número de ventas del producto #3: 9
# Día 4
# Número de ventas del producto #1: 10
# Número de ventas del producto #2: 11
# Número de ventas del producto #3: 12
# Día 5
# Número de ventas del producto #1: 13
# Número de ventas del producto #2: 14
# Número de ventas del producto #3: 15

# %%
#Juntamos los arrays de las ventas junto con el de los precios y le damos la forma y transponemos las los arrays para que tengan la forma deseada
a = np.concatenate(([price],[ventas_0], [ventas_1],[ventas_2],[ventas_3],[ventas_4]), axis=0)
a_t = a.transpose() #Transponemos el array anterior para que quede de forma vertical
products = np.array(["Producto #1","Producto #2","Producto #3"]) #Generamos un array con el nombre de los productos para que sean el nombre de nuestras filas
price_t = price.transpose() #Transponemos el array de los precios para que quede de forma vertical

# %%
days =["Precio Unitario","Dia 1","Dia 2","Dia 3","Dia 4","Dia 5"] #Generamos una lista la cual va a ser el nombre de las columnas
tabla = pd.DataFrame(data=a_t,index= np.array(products), columns=days) #Generamos un dataframe con los nombres de las filas y de las columnas, con los datos
prices_df = pd.DataFrame(price_t, columns= ["Precio Unitario"], index = np.array(products)) #Generamos un DF con los precios 

total = np.zeros(len(days)) #Generamos un array de puros ceros con el tamaño del número de días
#Hacemos un doble loop donde vamos a realizar las sumas y vamos a generar un array con el valor de las ventas de los 5 días con sus descuentas
for i in range (len(days)):
  x = 0
  for j in range(len(products)):
    suma = a[i,j]*price[j]
    if i == 0:
      continue
    else:
      x += suma
  total[i] = x
desc = total*.95
#Generamos los DF con los arrays anteriores
desc_df = pd.DataFrame(desc,columns=["5% Desc"],index=days).transpose()
total_df = pd.DataFrame(total,columns=["Total"],index=days).transpose()
#Unimos los DF con la función concat
tabla = pd.concat([tabla,total_df,desc_df])
tabla
# Out:
#              Precio Unitario  Dia 1  Dia 2  Dia 3  Dia 4  Dia 5
# Producto #1              1.0    1.0    4.0    7.0   10.0   13.0
# Producto #2              2.0    2.0    5.0    8.0   11.0   14.0
# Producto #3              3.0    3.0    6.0    9.0   12.0   15.0
# Total                    0.0   14.0   32.0   50.0   68.0   86.0
# 5% Desc                  0.0   13.3   30.4   47.5   64.6   81.7

# %% [markdown]
# ### **Ejercicio 2**

# %%
import numpy as np
#Generamos un diccionario donde vamos a guardar los meses y los ingresos en dichos meses
ingresos = {'Enero' : 1 , 'Febrero' : 2 , 'Marzo' : 3 , 'Abril' : 4 , 'Mayo' : 5 , 'Junio' : 6 , 'Julio' : 7 , 
           'Agosto' : 8 , 'Septiembre' : 9 , 'Octubre' : 10 , 'Noviembre' : 11 , 'Diciembre': 12}
#Le pedimos al usuario que ingrese el diccionario (podemos usar el anterior como ejemplo)
x = (input("Inserte los ingresos mensuales: "))
#Mostramos que los datos estén bien, su tamaño y el tipo de variable que es
print(x)
print(len(ingresos))
type(x)
# Out:
# Inserte los ingresos mensuales: {'Enero' : 1 , 'Febrero' : 2 , 'Marzo' : 3 , 'Abril' : 4 , 'Mayo' : 5 , 'Junio' : 6 , 'Julio' : 7 ,             'Agosto' : 8 , 'Septiembre' : 9 , 'Octubre' : 10 , 'Noviembre' : 11 , 'Diciembre': 12}
# {'Enero' : 1 , 'Febrero' : 2 , 'Marzo' : 3 , 'Abril' : 4 , 'Mayo' : 5 , 'Junio' : 6 , 'Julio' : 7 ,             'Agosto' : 8 , 'Septiembre' : 9 , 'Octubre' : 10 , 'Noviembre' : 11 , 'Diciembre': 12}
# 12
# str

# %%
#Hacemos que nuestra variable anterior sea tomada de forma literal, generando así el diccionario con el cual vamos a trabajar
import ast
x = ast.literal_eval(x)
type(x)
# Out:
# dict

# %%
import pandas as pd
y = np.array(list(x.values())) #Generamos un array con los valores de nuestro diccionario
print(f"Mínimo= {y.min()}, Máximo= {y.max()}, Media= {y.mean()}") #Mostramos los valores estadísticos que nos pidieron
serie = pd.Series(data=[y.min(),y.max(),y.mean()]) #Generamos una serie con los valores estadísticos solicitados
serie
# Out:
# Mínimo= 1, Máximo= 12, Media= 6.5
# 0     1.0
# 1    12.0
# 2     6.5
# dtype: float64

# %% [markdown]
# ### **Ejercicio** 3

# %%
import pandas as pd
import numpy as np
#Generamos los arrays con los valores solicitados
a = np.array(['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo'])
b = np.array(['30500', '35600', '28300', '33900', '42500'])
c = np.array(['22000', '23450', '18100', '35700', '32450'])
#Generamos un array más, el cual va a ser útil para el nombre de nuestras columnas
d = np.array(["Mes","Ventas","Gastos"])
#Generamos un DF con los 3 arrays anteriores, con el nombre de las columnas el el lugar del index y lo transponemos para darle el formato adecuado
df = pd.DataFrame(data= [a,b,c],columns= None, index= d).transpose()
print(df)
#Creamos 3 listas con el mismo número de entradas que los meses de nuestro primer array
gv = [0]*len(a)
ms = [0]*len(a)
sg = [0]*len(a)
#Usamos una loop para generar las entradas de las 3 listas anteriores
for i in range (len(a)):
  gv[i] += int(c[i])/int(b[i])*100
  if int(b[i])>=30000:
    ms[i] = "Meta Superada"
  else:
    ms[i] = "Meta no Superada"
  if int(c[i])>int(b[i]):
    sg[i] += int(c[i])-int(b[i])
#Generamos los valores requeridos y los imprimimos
l3m = int(b[-1])+int(b[-2])+int(b[-3])
print(l3m)
gfa = int(c[1])+int(c[2])+int(c[3])
print(gfa)
#Agregamos al DF los arrays generados en el orden correspondiente
df.insert(1, 'Sobre Gasto', sg)
df.insert(1, 'Metas', ms)
df.insert(1, 'Gasto/Venta*100', gv)
df
# Out:
#        Mes Ventas Gastos
# 0    Enero  30500  22000
# 1  Febrero  35600  23450
# 2    Marzo  28300  18100
# 3    Abril  33900  35700
# 4     Mayo  42500  32450
# 104700
# 77250
#        Mes  Gasto/Venta*100             Metas  Sobre Gasto Ventas Gastos
# 0    Enero        72.131148     Meta Superada            0  30500  22000
# 1  Febrero        65.870787     Meta Superada            0  35600  23450
# 2    Marzo        63.957597  Meta no Superada            0  28300  18100
# 3    Abril       105.309735     Meta Superada         1800  33900  35700
# 4     Mayo        76.352941     Meta Superada            0  42500  32450

# %% [markdown]
# ### **Ejercicio 4**

# %%
#Cargamos la data desde nuestra PC
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3f27af04-e3fb-49b4-8817-e933465d2f43" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f27af04-e3fb-49b4-8817-e933465d2f43">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data - Riesgos.csv to Data - Riesgos.csv
# ...

# %%
import pandas as pd
#levantamos la data con pandas
df = pd.read_csv('Data - Riesgos.csv')

print(df.shape) #Muestra las dimensiones del dataframe (filas,columnas)
print(df.shape[0]*df.shape[1]) #Muestra el número de datos que hay en el dataframe
print(df.columns.values) #Muestra un narray con los nombres de las columnas
print(df.index.values) #Muestra un narray con los nombres de las filas
print(df.info()) #Muestra los tipos de datos de las columnas
print(df.head(10)) #Muestra los primeros 10 datos
print(df.tail(10)) #Muestra los últimos 10 datos
print(pd.DataFrame(df.isna().sum(), columns = ['Perdidos']))#Muestra el total datos perdidos
# Out:
# (4500, 10)
# 45000
# ['ID' 'edad' 'meses' 'max_ant' 'ingreso' 'score' 'tipo_vivienda' 'zona'
#  'nivel' 'riesgo']
# [   0    1    2 ... 4497 4498 4499]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             4500 non-null   int64
#  1   edad           4487 non-null   float64
#  2   meses          4494 non-null   float64
#  3   max_ant        4496 non-null   float64
#  4   ingreso        4495 non-null   float64
#  5   score          4495 non-null   float64
#  6   tipo_vivienda  4500 non-null   int64
#  7   zona           4494 non-null   float64
#  8   nivel          4500 non-null   int64
#  9   riesgo         4500 non-null   int64
# dtypes: float64(6), int64(4)
# memory usage: 351.7 KB
# None
#      ID  edad  meses  max_ant  ...  tipo_vivienda  zona  nivel  riesgo
# ...

# %%
df100 = df.head(100) #Guardamos las 100 primeras filas
df100
# Out:
#       ID  edad  meses  max_ant  ...  tipo_vivienda  zona  nivel  riesgo
# 0   2208  33.0  128.0      6.0  ...              2   3.0      2       1
# 1   2211  32.0  185.0      7.0  ...              2   1.0      5       1
# 2   2212  28.0    NaN      7.0  ...              2   1.0      2       1
# 3   2216  56.0  200.0      0.0  ...              2   1.0      5       1
# 4   2218  32.0  131.0     65.0  ...              2   1.0      2       1
# ..   ...   ...    ...      ...  ...            ...   ...    ...     ...
# 95  2387  41.0  141.0      0.0  ...              4   2.0      1       1
# 96  2389  29.0  159.0     17.0  ...              2   4.0      2       1
# 97  2391  27.0  122.0      NaN  ...              2   1.0      2       1
# 98  2392  35.0  111.0      0.0  ...              2   1.0      5       1
# 99  2394  28.0  137.0      0.0  ...              3   1.0      5       1
#
# [100 rows x 10 columns]
